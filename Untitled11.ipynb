# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import warnings

# %%
df=pd.read_csv('/content/Student_Performance.csv')
print('Success')
# Out:
# Success

# %%
df.head(10)
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
# 5              3               78                         No            9
# 6              7               73                        Yes            5
# 7              8               45                        Yes            4
# 8              5               77                         No            8
# 9              4               89                         No            4
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0
# 5                                 6               61.0
# 6                                 6               63.0
# 7                                 6               42.0
# 8                                 2               61.0
# 9                                 0               69.0

# %%
df.tail()
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
df.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
plt.scatter(df['Hours Studied'], df['Performance Index'])
plt.xlabel('Hours Studied')
plt.ylabel('Performance')
plt.title('Hours Studied vs. Preformance Index')
plt.show()

# %%
#Conclusion: Performance index is improving wrt hours of studies
df.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
sns.barplot(x='Extracurricular Activities', y='Performance Index', data=df)
# Out:
# <Axes: xlabel='Extracurricular Activities', ylabel='Performance Index'>

# %%
avg_perf=df.groupby('Hours Studied')['Performance Index'].mean()

# %%
plt.plot(avg_perf.index,avg_perf.values)
plt.xlabel('Hours Studied')
plt.ylabel('Average Performance Index')
plt.show()

# %%
sns.violinplot(y='Performance Index', x='Sample Question Papers Practiced',data=df)
plt.xlabel('Sample Question Papers Practiced')
plt.ylabel('Performance Label')
plt.title('Sample Question Papers Practiced by Performance Level')
plt.show()
#used for average or mean

# %%
#correlation matrix
df.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
Corr_mat= df[['Hours Studied', 'Previous Scores', 'Extracurricular Activities','Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index']].corr()
sns.heatmap(Corr_mat, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# <ipython-input-24-1af6b78f3efd>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Corr_mat= df[['Hours Studied', 'Previous Scores', 'Extracurricular Activities','Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index']].corr()

# %%
sns.pairplot(data=df[['Hours Studied', 'Previous Scores', 'Extracurricular Activities', 'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index']])
plt.title('Pairwise Relationships')
plt.show()

# %%
df.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
X=df.drop("Performance Index",axis=1)
Y=df["Performance Index"]

# %%
#Splitting data into Train and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test= train_test_split(X,Y,test_size=0.2, random_state=42)

# %%
x_train.shape
# Out:
# (8000, 5)

# %%
y_train.shape
# Out:
# (8000,)

# %%
x_test.shape
# Out:
# (2000, 5)

# %%
y_test.shape
# Out:
# (2000,)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %% [markdown]
# Extracurricalar activities is in object type, convert it into numerical type

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
x_train["Extracurricular Activities"]=encoder.fit_transform(x_train["Extracurricular Activities"])
x_test["Extracurricular Activities"]=encoder.transform(x_test["Extracurricular Activities"])

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8000 entries, 9254 to 7270
# Data columns (total 5 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     8000 non-null   int64
#  1   Previous Scores                   8000 non-null   int64
#  2   Extracurricular Activities        8000 non-null   int64
#  3   Sleep Hours                       8000 non-null   int64
#  4   Sample Question Papers Practiced  8000 non-null   int64
# dtypes: int64(5)
# memory usage: 375.0 KB

# %%
#Training  a simple linear regression model
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)
y_pred=np.round_(y_pred,decimals=2)

# %%
# Real Values vs Predicted Values
pd.DataFrame({'Actual Performance': y_test, 'Predicted Performance': y_pred})
# Out:
#       Actual Performance  Predicted Performance
# 6252                51.0                  54.71
# 4684                20.0                  22.62
# 1731                46.0                  47.90
# 4742                28.0                  31.29
# 4521                41.0                  43.00
# ...                  ...                    ...
# 6412                45.0                  46.89
# 8285                66.0                  62.70
# 7853                16.0                  16.79
# 1095                65.0                  63.34
# 6929                47.0                  45.94
#
# [2000 rows x 2 columns]

# %%
from sklearn.metrics import r2_score, mean_squared_error
r2 = r2_score(y_test, y_pred)
mean_er = mean_squared_error(y_test, y_pred)

# %%
print('Mean Squared Error : ', mean_er)
print('R Square : ', r2)
# Out:
# Mean Squared Error :  4.0826094
# R Square :  0.9889833422235986

# %%
print(regressor.coef_)
print(regressor.intercept_)
# Out:
# [2.85248393 1.0169882  0.60861668 0.47694148 0.19183144]
# -33.92194621555638

# %% [markdown]
# Therefore, the equation of our multiple linear regression model is:
#
# Student Performance = 2.85×Hours Studied + 1.02×Previous Scores + 0.61×Extracurricular Activities + 0.48×Sleep Hours + 0.19×Sample Question Papers Practiced - 33.92

# %%
import statsmodels.api as sm

# Add a constant
X_train = sm.add_constant(x_train)

# Create a first fitted model
lr1 = sm.OLS(y_train, x_train).fit()

# %%
# Check the parameters obtained

lr1.params
# Out:
# Hours Studied                       2.214373
# Previous Scores                     0.816562
# Extracurricular Activities         -1.213969
# Sleep Hours                        -1.492101
# Sample Question Papers Practiced   -0.275522
# dtype: float64

# %%
  # Print a summary of the linear regression model obtained
print(lr1.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:      Performance Index   R-squared (uncentered):                   0.990
# Model:                            OLS   Adj. R-squared (uncentered):              0.990
# Method:                 Least Squares   F-statistic:                          1.617e+05
# Date:                Thu, 03 Aug 2023   Prob (F-statistic):                        0.00
# Time:                        09:19:16   Log-Likelihood:                         -25405.
# No. Observations:                8000   AIC:                                  5.082e+04
# Df Residuals:                    7995   BIC:                                  5.086e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Hours Studied                        2.2144      0.024     93.109      0.000       2.168       2.261
# Previous Scores                      0.8166      0.003    284.752      0.000       0.811       0.822
# Extracurricular Activities          -1.2140      0.128     -9.501      0.000      -1.464      -0.963
# Sleep Hours                         -1.4921      0.030    -49.675      0.000      -1.551      -1.433
# Sample Question Papers Practiced    -0.2755      0.022    -12.552      0.000      -0.319      -0.232
# ==============================================================================
# Omnibus:                       41.846   Durbin-Watson:                   1.926
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.250
# Skew:                          -0.007   Prob(JB):                     2.70e-07
# Kurtosis:                       2.699   Cond. No.                         143.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
